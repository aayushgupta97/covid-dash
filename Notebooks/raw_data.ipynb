# %%
import pandas as pd
import requests
import numpy as np

# %%
r1 = requests.get("https://api.covid19india.org/raw_data1.json").json()
r2 = requests.get("https://api.covid19india.org/raw_data2.json").json()
r3 = requests.get("https://api.covid19india.org/raw_data3.json").json()

# %%
r1.keys(), r2.keys(), r3.keys()
# Out:
# (dict_keys(['raw_data']), dict_keys(['raw_data']), dict_keys(['raw_data']))

# %%
gender = pd.DataFrame(r1['raw_data'])['gender']

# %%
type(gender)
# Out:
# pandas.core.series.Series

# %%
import plotly.graph_objects as go

# %%
go.Pie(values=gender)
# Out:
# array(['F', '', '', ..., 'M', 'M', 'M'], dtype=object)

# %%
gender.value_counts()['M']
# Out:
# 2523

# %%
pd.DataFrame(r1['raw_data'])[['gender', 'agebracket']]
# Out:
#       gender agebracket
# 0          F         20
# 1
# 2
# 3          M         45
# 4          M         24
# ...      ...        ...
# 17301
# 17302
# 17303      M         30
# 17304      M         36
# 17305      M         52
#
# [17306 rows x 2 columns]

# %%
df1 = pd.DataFrame(r1['raw_data'])[['gender', 'agebracket']]
df2 = pd.DataFrame(r2['raw_data'])[['gender', 'agebracket']]
df3 = pd.DataFrame(r3['raw_data'])[['gender', 'agebracket']]

# %%
raw_df = pd.concat([df1,df2,df3])

# %%
raw_df['agebracket'].value_counts()
# Out:
#        27848
# 35       140
# 40       128
# 30       125
# 32       125
#        ...
# 96         1
# 1.5        1
# 0.3        1
# 89         1
# 83         1
# Name: agebracket, Length: 95, dtype: int64

# %%
raw_df['gender'].value_counts()
# Out:
#               24890
# M              4678
# F              2401
# Non-Binary        1
# Name: gender, dtype: int64

# %%
"A"> 0
# Out:
# --------------------------------------------------------------------
# TypeError                          Traceback (most recent call last)
# <ipython-input-29-fdb7d3445c03> in <module>
# ----> 1 "A"> 0
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %%
df1['agebracket'].value_counts()
# Out:
#        15636
# 35        67
# 32        52
# 40        49
# 55        45
#        ...
# 96         1
# 1.5        1
# 89         1
# 92         1
# 79         1
# Name: agebracket, Length: 89, dtype: int64

# %%
bool(df1['agebracket'][0])
# Out:
# True

# %%
a = df1['agebracket'].apply(lambda x: x if bool(x) else np.nan)

# %%
a.dropna(inplace=True)

# %%
a
# Out:
# 0        20
# 3        45
# 4        24
# 5        69
# 6        55
#          ..
# 16135    30
# 16136    50
# 17303    30
# 17304    36
# 17305    52
# Name: agebracket, Length: 1670, dtype: object

# %%
df1
# Out:
#       gender agebracket
# 0          F         20
# 1
# 2
# 3          M         45
# 4          M         24
# ...      ...        ...
# 17301
# 17302
# 17303      M         30
# 17304      M         36
# 17305      M         52
#
# [17306 rows x 2 columns]

# %%
df = pd.DataFrame(r1['raw_data'])

# %%
df
# Out:
#       agebracket                                 backupnotes  \
# 0             20                          Student from Wuhan
# 1                                         Student from Wuhan
# 2                                         Student from Wuhan
# 3             45         Travel history to Italy and Austria
# 4             24  Travel history to Dubai, Singapore contact
# ...          ...                                         ...
# 17301
# 17302
# 17303         30
# 17304         36
# 17305         52
#
#       contractedfromwhichpatientsuspected currentstatus dateannounced  \
# 0                                             Recovered    30/01/2020
# 1                                             Recovered    02/02/2020
# 2                                             Recovered    03/02/2020
# 3                                             Recovered    02/03/2020
# 4                                             Recovered    02/03/2020
# ...                                   ...           ...           ...
# 17301                                      Hospitalized    19/04/2020
# 17302                                      Hospitalized    19/04/2020
# 17303                                      Hospitalized    19/04/2020
# 17304                                      Hospitalized    19/04/2020
# 17305                                      Hospitalized    19/04/2020
#
#                    detectedcity detecteddistrict      detectedstate  \
# 0                      Thrissur         Thrissur             Kerala
# 1                     Alappuzha        Alappuzha             Kerala
# 2                     Kasaragod        Kasaragod             Kerala
# 3      East Delhi (Mayur Vihar)       East Delhi              Delhi
# 4                     Hyderabad        Hyderabad          Telangana
# ...                         ...              ...                ...
# 17301                                  Bandipora  Jammu and Kashmir
# 17302                                  Baramulla  Jammu and Kashmir
# 17303                                     Munger              Bihar
# 17304                                     Munger              Bihar
# 17305                                     Munger              Bihar
#
#       estimatedonsetdate gender nationality  \
# 0                             F       India
# 1                                     India
# 2                                     India
# 3                             M       India
# 4                             M       India
# ...                  ...    ...         ...
# 17301
# 17302
# 17303                         M
# 17304                         M
# 17305                         M
#
#                                                    notes patientnumber  \
# 0                                   Travelled from Wuhan             1
# 1                                   Travelled from Wuhan             2
# 2                                   Travelled from Wuhan             3
# 3                          Travelled from Austria, Italy             4
# 4      Travelled from Dubai to Bangalore on 20th Feb,...             5
# ...                                                  ...           ...
# 17301                                    Details awaited         17301
# 17302                                    Details awaited         17302
# 17303                                    Details awaited         17303
# 17304                                    Details awaited         17304
# 17305                                    Details awaited         17305
#
#                                                  source1  \
# 0      https://twitter.com/vijayanpinarayi/status/122...
# 1      https://www.indiatoday.in/india/story/kerala-r...
# 2      https://www.indiatoday.in/india/story/kerala-n...
# 3      https://www.indiatoday.in/india/story/not-a-ja...
# 4      https://www.deccanherald.com/national/south/qu...
# ...                                                  ...
# 17301  https://twitter.com/kansalrohit69/status/12519...
# 17302  https://twitter.com/kansalrohit69/status/12519...
# 17303  https://twitter.com/sanjayjavin/status/1251938...
# 17304  https://twitter.com/sanjayjavin/status/1251938...
# 17305  https://twitter.com/sanjayjavin/status/1251938...
#
#                                                  source2  \
# 0      https://weather.com/en-IN/india/news/news/2020...
# 1      https://weather.com/en-IN/india/news/news/2020...
# 2      https://twitter.com/ANI/status/122422148580539...
# 3      https://economictimes.indiatimes.com/news/poli...
# 4      https://www.indiatoday.in/india/story/coronavi...
# ...                                                  ...
# 17301
# 17302
# 17303
# 17304
# 17305
#
#                                                  source3 statecode  \
# 0                                                               KL
# 1                                                               KL
# 2      https://weather.com/en-IN/india/news/news/2020...        KL
# 3                                                               DL
# 4      https://www.thehindu.com/news/national/coronav...        TG
# ...                                                  ...       ...
# 17301                                                           JK
# 17302                                                           JK
# 17303                                                           BR
# 17304                                                           BR
# 17305                                                           BR
#
#       statepatientnumber statuschangedate typeoftransmission
# 0               KL-TS-P1       14/02/2020           Imported
# 1               KL-AL-P1       14/02/2020           Imported
# 2               KL-KS-P1       14/02/2020           Imported
# 3                  DL-P1       15/03/2020           Imported
# 4                  TS-P1       02/03/2020           Imported
# ...                  ...              ...                ...
# 17301                          19/04/2020
# 17302                          19/04/2020
# 17303                          19/04/2020
# 17304                          19/04/2020
# 17305                          19/04/2020
#
# [17306 rows x 20 columns]

# %%
df[['notes', 'source1']]
# Out:
#                                                    notes  \
# 0                                   Travelled from Wuhan
# 1                                   Travelled from Wuhan
# 2                                   Travelled from Wuhan
# 3                          Travelled from Austria, Italy
# 4      Travelled from Dubai to Bangalore on 20th Feb,...
# ...                                                  ...
# 17301                                    Details awaited
# 17302                                    Details awaited
# 17303                                    Details awaited
# 17304                                    Details awaited
# 17305                                    Details awaited
#
#                                                  source1
# 0      https://twitter.com/vijayanpinarayi/status/122...
# 1      https://www.indiatoday.in/india/story/kerala-r...
# 2      https://www.indiatoday.in/india/story/kerala-n...
# 3      https://www.indiatoday.in/india/story/not-a-ja...
# 4      https://www.deccanherald.com/national/south/qu...
# ...                                                  ...
# 17301  https://twitter.com/kansalrohit69/status/12519...
# 17302  https://twitter.com/kansalrohit69/status/12519...
# 17303  https://twitter.com/sanjayjavin/status/1251938...
# 17304  https://twitter.com/sanjayjavin/status/1251938...
# 17305  https://twitter.com/sanjayjavin/status/1251938...
#
# [17306 rows x 2 columns]

# %%
raw_df['detectedstate'].value_counts()
# Out:
# -------------------------------------------------------------------------
# KeyError                                Traceback (most recent call last)
# ~/miniconda3/envs/covid/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'detectedstate'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                Traceback (most recent call last)
# <ipython-input-82-75342310edf9> in <module>
# ----> 1 raw_df['detectedstate'].value_counts()
#
# ~/miniconda3/envs/covid/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~/miniconda3/envs/covid/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'detectedstate'

# %%
raw_df
# Out:
#      gender agebracket
# 0         F         20
# 1
# 2
# 3         M         45
# 4         M         24
# ...     ...        ...
# 4074
# 4075
# 4076
# 4077
# 4078
#
# [31970 rows x 2 columns]

# %%
df1 = pd.DataFrame(r1['raw_data'])
df2 = pd.DataFrame(r2['raw_data'])
df3 = pd.DataFrame(r3['raw_data'])
raw = pd.concat([df1, df2, df3])

# %%
raw['detectedstate'].value_counts()
# Out:
# Maharashtra                    8320
# Tamil Nadu                     4172
# Gujarat                        3707
# Delhi                          2938
# Rajasthan                      2435
# Madhya Pradesh                 2278
# Uttar Pradesh                  2154
# Andhra Pradesh                 1706
# Telangana                      1029
# Karnataka                       831
#                                 793
# West Bengal                     681
# Jammu and Kashmir               626
# Bihar                           570
# Kerala                          565
# Punjab                          442
# Haryana                         376
# Odisha                          186
# Chandigarh                      108
# Jharkhand                       102
# Uttarakhand                      67
# Himachal Pradesh                 53
# Chhattisgarh                     50
# Assam                            47
# Andaman and Nicobar Islands      38
# Ladakh                           25
# Meghalaya                        15
# Puducherry                       12
# Goa                               7
# Tripura                           5
# Manipur                           2
# Arunachal Pradesh                 1
# Mizoram                           1
# Name: detectedstate, dtype: int64

# %%
raw
# Out:
#      agebracket                                 backupnotes  \
# 0            20                          Student from Wuhan
# 1                                        Student from Wuhan
# 2                                        Student from Wuhan
# 3            45         Travel history to Italy and Austria
# 4            24  Travel history to Dubai, Singapore contact
# ...         ...                                         ...
# 6446                                                    NaN
# 6447                                                    NaN
# 6448                                                    NaN
# 6449                                                    NaN
# 6450                                                    NaN
#
#      contractedfromwhichpatientsuspected currentstatus dateannounced  \
# 0                                            Recovered    30/01/2020
# 1                                            Recovered    02/02/2020
# 2                                            Recovered    03/02/2020
# 3                                            Recovered    02/03/2020
# 4                                            Recovered    02/03/2020
# ...                                  ...           ...           ...
# 6446                                                      05/05/2020
# 6447                                                      05/05/2020
# 6448                                                      05/05/2020
# 6449                                                      05/05/2020
# 6450                                                      05/05/2020
#
#                   detectedcity detecteddistrict detectedstate  \
# 0                     Thrissur         Thrissur        Kerala
# 1                    Alappuzha        Alappuzha        Kerala
# 2                    Kasaragod        Kasaragod        Kerala
# 3     East Delhi (Mayur Vihar)       East Delhi         Delhi
# 4                    Hyderabad        Hyderabad     Telangana
# ...                        ...              ...           ...
# 6446
# 6447
# 6448
# 6449
# 6450
#
#      estimatedonsetdate gender  ... patientnumber  \
# 0                            F  ...             1
# 1                               ...             2
# 2                               ...             3
# 3                            M  ...             4
# 4                            M  ...             5
# ...                 ...    ...  ...           ...
# 6446                NaN         ...
# 6447                NaN         ...
# 6448                NaN         ...
# 6449                NaN         ...
# 6450                NaN         ...
#
#                                                 source1  \
# 0     https://twitter.com/vijayanpinarayi/status/122...
# 1     https://www.indiatoday.in/india/story/kerala-r...
# 2     https://www.indiatoday.in/india/story/kerala-n...
# 3     https://www.indiatoday.in/india/story/not-a-ja...
# 4     https://www.deccanherald.com/national/south/qu...
# ...                                                 ...
# 6446
# 6447
# 6448
# 6449
# 6450
#
#                                                 source2  \
# 0     https://weather.com/en-IN/india/news/news/2020...
# 1     https://weather.com/en-IN/india/news/news/2020...
# 2     https://twitter.com/ANI/status/122422148580539...
# 3     https://economictimes.indiatimes.com/news/poli...
# 4     https://www.indiatoday.in/india/story/coronavi...
# ...                                                 ...
# 6446
# 6447
# 6448
# 6449
# 6450
#
#                                                 source3 statecode  \
# 0                                                              KL
# 1                                                              KL
# 2     https://weather.com/en-IN/india/news/news/2020...        KL
# 3                                                              DL
# 4     https://www.thehindu.com/news/national/coronav...        TG
# ...                                                 ...       ...
# 6446
# 6447
# 6448
# 6449
# 6450
#
#      statepatientnumber statuschangedate typeoftransmission entryid numcases
# 0              KL-TS-P1       14/02/2020           Imported     NaN      NaN
# 1              KL-AL-P1       14/02/2020           Imported     NaN      NaN
# 2              KL-KS-P1       14/02/2020           Imported     NaN      NaN
# 3                 DL-P1       15/03/2020           Imported     NaN      NaN
# 4                 TS-P1       02/03/2020           Imported     NaN      NaN
# ...                 ...              ...                ...     ...      ...
# 6446
# 6447
# 6448
# 6449
# 6450
#
# [34342 rows x 22 columns]

# %%
df1.shape, df2.shape, df3.shape
# Out:
# ((17306, 20), (10585, 20), (6451, 20))

# %%
import requests
import pandas as pd

# %%
r = requests.get("https://api.covid19india.org/data.json")

# %%
dc = r.json()

# %%
dc.keys()
# Out:
# dict_keys(['cases_time_series', 'statewise', 'tested'])

# %%
df = pd.DataFrame(dc['cases_time_series'])

# %%
df
# Out:
#    dailyconfirmed dailydeceased dailyrecovered          date totalconfirmed  \
# 0               1             0              0   30 January               1
# 1               0             0              0   31 January               1
# 2               0             0              0  01 February               1
# 3               1             0              0  02 February               2
# 4               1             0              0  03 February               3
# ..            ...           ...            ...           ...            ...
# 90           1705            71            690     29 April           33065
# 91           1801            75            630     30 April           34866
# 92           2396            77            962       01 May           37262
# 93           2567            92            831       02 May           39829
# 94           2676            68            923       03 May           42505
#
#    totaldeceased totalrecovered
# ...

# %%
df1 = pd.DataFrame(dc['statewise'])

# %%
df1
# Out:
#    active confirmed deaths deltaconfirmed deltadeaths deltarecovered  \
# 0   32321     46860   1575            426           9            115
# 1   11493     14541    583              0           0              0
# 2    4290      5804    319              0           0              0
# 3    3403      4898     64              0           0              0
# 4    2110      3550     31              0           0              0
# 5    1581      3127     82             66           5             26
# 6    1921      2942    165              0           0              0
# 7    1914      2766     50              0           0              0
# 8    1094      1717     34             67           1             65
# 9     908      1259    133              0           0              0
# 10   1293      1451     25            219           2              5
# 11    471      1085     29              0           0              0
# 12    415       726      8              0           0              0
# ...

# %%
df2 = pd.DataFrame(dc['tested'])
df2
# Out:
#    individualstestedperconfirmedcase positivecasesfromsamplesreported  \
# 0                        75.64102564
# 1                        81.56666667
# 2                        73.96428571
# 3                        72.99450549
# 4                        65.46601942
# 5                               61.5
# 6                        54.65313653
# 7                        50.86031746
# 8                        47.24046921
# 9                        43.52777778
# 10                       42.15180723
# 11                       42.07430998
# 12                       41.43983402
# 13                       40.67910448
# 14                       40.88682746
# 15                       41.74526678
# 16
# 17
# 18                       38.78147612
# 19
# 20
# 21                                 0
# 22                                 0
# 23                                 0
# 24                                 0                              575
# 25                                 0
# ...

# %%
df['date'][31:]
# Out:
# 31    01 March
# 32    02 March
# 33    03 March
# 34    04 March
# 35    05 March
#         ...
# 90    29 April
# 91    30 April
# 92      01 May
# 93      02 May
# 94      03 May
# Name: date, Length: 64, dtype: object

# %%
df1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6a861a8b3f1a> in <module>
# ----> 1 df1
#
# NameError: name 'df1' is not defined

# %%
df1.sort_values(by=["confirmed"], ascending=False)
# Out:
#    active  confirmed deaths deltaconfirmed deltadeaths deltarecovered  \
# 0   32321      46860   1575            426           9            115
# 1   11493      14541    583              0           0              0
# 2    4290       5804    319              0           0              0
# 3    3403       4898     64              0           0              0
# 4    2110       3550     31              0           0              0
# 5    1581       3127     82             66           5             26
# 6    1921       2942    165              0           0              0
# 7    1914       2766     50              0           0              0
# 8    1094       1717     34             67           1             65
# 10   1293       1451     25            219           2              5
# 9     908       1259    133              0           0              0
# 11    471       1085     29              0           0              0
# ...

# %%
df1['confirmed'] = df1['confirmed'].astype(int)
